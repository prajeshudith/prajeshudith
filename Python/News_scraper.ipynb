# %%
# Instaling required packages

# %%
pip install newsapi-python
# Out:
# Collecting newsapi-python
#   Downloading newsapi_python-0.2.6-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: requests<3.0.0 in c:\users\admin\anaconda3\lib\site-packages (from newsapi-python) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2.8)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
#Loading packages

# %%
from newsapi.newsapi_client import NewsApiClient
import json
import pandas as pd
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
# Inserting keyword

# %%
keywords = input('Enter the word for search: ').split()
# Out:
# Enter the word for search: zach charbonnet

# %%
# Fetching data from different platforms

# %%
for word in keywords:
     api = NewsApiClient(api_key="b5bb23a524ff49eab93bf121027c9bb8")
     result = api.get_everything(word, sort_by="publishedAt", language="en")
     print(result)
# Out:
# {'status': 'ok', 'totalResults': 4085, 'articles': [{'source': {'id': None, 'name': 'Raw Story'}, 'author': 'Sky Palma', 'title': 'Trump called out after a close analysis of his statements reveals ‘a persistent sympathy for Putin’', 'description': 'In a statement posted to his website this Monday, former President Donald Trump posted a statement to his website expressing his displeasure over Russia\'s invasion of Ukraine. "It doesn’t make sense that Russia and Ukraine aren’t sitting down and working out …', 'url': 'https://www.rawstory.com/trump-putin-2657185163/', 'urlToImage': 'https://www.rawstory.com/media-library/image.jpg?id=29703413&width=1200&coordinates=0%2C0%2C0%2C50&height=600', 'publishedAt': '2022-04-20T17:00:22Z', 'content': 'Alas, if Marchant manages to get elected to the office he is seeking, he will be in a position to do absolutely exactly and beyond a shadow of a doubt nothing at all in any way whatsoever that would … [+5826 chars]'}, {'source': {'id': None, 'name': 'Heat.com'}, 'author': 'Bulls.com', 'title': 'Chuck Checks In: Bulls fired up for Game 2 in Milwaukee', 'description': 'GAME NIGHT FROM MILWAUKEE: Bulls (0-1, 0-1 on the road) at Bucks: ( 1-0, 1-0 at home). 8:30pm RADIO: WBBM 780/ 670 THE SCORE: Chuck Swirsky and Bill Wennington. 8:15 pregame LEADING SCORERS: Bulls- Vucevic (24 pts), Bucks- Antetokounmpo (28 pts) LEADING REBOU…', 'url': 'https://www.nba.com/bulls/news/chuck-checks-bulls-fired-game-2-milwaukee', 'urlToImage': 'https://www.nba.com/bulls/sites/bulls/files/caruso_16x9_fire.jpg?cw=700&ch=500&w=889&h=500&x=95&y=0', 'publishedAt': '2022-04-20T16:52:08Z', 'content': 'GAME NIGHT FROM MILWAUKEE: Bulls (0-1, 0-1 on the road) at Bucks: ( 1-0, 1-0 at home). 8:30pm \r\nRADIO: WBBM 780/ 670 THE SCORE: Chuck Swirsky and Bill Wennington. 8:15 pregame\r\nLEADING SCORERS: Bulls… [+1229 chars]'}, {'source': {'id': None, 'name': 'Raw Story'}, 'author': 'David Edwards', 'title': "Marjorie Taylor Greene melts down over Jan. 6 lawsuit: 'They are actually putting me on the witness stand!'", 'description': 'Rep. Marjorie Taylor Green (R-GA) this week claimed that she is being "forced" to testify on her own behalf after a group of voters sued to have her removed from the ballot.Judge Amy Totenberg ruled this week that the lawsuit against Greene could go forward. …', 'url': 'https://www.rawstory.com/marjorie-taylor-greene-january-6-lawsuit/', 'urlToImage': 'https://www.rawstory.com/media-library/dan-ball-and-marjorie-taylor-greene.jpg?id=29703316&width=1200&coordinates=0%2C0%2C0%2C50&height=600', 'publishedAt': '2022-04-20T16:47:48Z', 'content': 'Alas, if Marchant manages to get elected to the office he is seeking, he will be in a position to do absolutely exactly and beyond a shadow of a doubt nothing at all in any way whatsoever that would … [+5826 chars]'}, {'source': {'id': None, 'name': 'Variety'}, 'author': 'Jennifer Maas', 'title': 'Irony Point Chiefs on the Potential for More ‘I Think You Should Leave,’ Marvel Podcast and Steering Clear of M&A (for Now)', 'description': 'Irony Point is a production company that might not yet be known widely by name, but its projects, Netflix’s critically acclaimed “I Think You Should Leave With Tim Robinson”; Paramount Plus’ revival of “Inside Amy Schumer” and Schumer’s recently renewed Hulu …', 'url': 'https://variety.com/2022/tv/news/irony-point-i-think-you-should-leave-season-3-marvel-squirrel-girl-podcast-1235231852/', 'urlToImage': 'https://variety.com/wp-content/uploads/2022/04/Irony-Point-co-presidents-Alex-Bach-and-Daniel-Powell.jpg?w=1000', 'publishedAt': '2022-04-20T16:45:53Z', 'content': 'Irony Point is a production company that might not yet be known widely by name, but its projects, Netflix’s critically acclaimed “I Think You Should Leave With Tim Robinson”; Paramount Plus’ revival … [+5256 chars]'}, {'source': {'id': None, 'name': 'CNET'}, 'author': 'Eli Blumenthal', 'title': 'T-Mobile Expands 5G Home Internet Availability By Another 10 Million Househo ...
# {'status': 'ok', 'totalResults': 33, 'articles': [{'source': {'id': None, 'name': 'Allthatsinteresting.com'}, 'author': 'Marco Margaritoff', 'title': 'The Extraordinary Life Of Betty Reid Soskin, America’s Oldest Park Ranger Who Is Retiring At Age 100', 'description': 'Betty Reid Soskin endured segregation, contributed to civilian efforts during World War II, and founded one of the first Black-owned record stores — all before becoming the oldest park ranger in America.\nThe post The Extraordinary Life Of Betty Reid Soskin, A…', 'url': 'https://allthatsinteresting.com/betty-reid-soskin', 'urlToImage': 'https://allthatsinteresting.com/wordpress/wp-content/uploads/2022/04/young-and-old-betty-soskin.jpg', 'publishedAt': '2022-04-05T19:45:47Z', 'content': 'Betty Reid Soskin endured segregation, contributed to civilian efforts during World War II, and founded one of the first Black-owned record stores all before becoming the oldest park ranger in Americ… [+6640 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'LA Times', 'title': "Commentary: Chip Kelly is gambling he doesn't have to match Lincoln Riley's electricity", 'description': 'With Lincoln Riley taking over at USC, all eyes and interest will be on the Trojans whether or not UCLA coach Chip Kelly and the Bruins can keep up.', 'url': 'https://news.yahoo.com/commentary-chip-kelly-gambling-doesnt-120044405.html', 'urlToImage': 'https://s.yimg.com/uu/api/res/1.2/qm2G4YAkP89bkJ44fELlAQ--~B/aD01NjA7dz04NDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/la_times_articles_853/a5b9ffc3e8535bf348a3e734e6910189', 'publishedAt': '2022-04-05T12:00:44Z', 'content': 'UCLA coach Chip Kelly during looks on during a game against Hawaii on Aug. 28, 2021, at the Rose Bowl. (Kyusung Gong / Associated Press)\r\nLast week at UCLA football practice, I asked Chip Kelly about… [+6400 chars]'}, {'source': {'id': None, 'name': 'Los Angeles Times'}, 'author': 'J. Brady McCollough', 'title': "Commentary: Chip Kelly is gambling he doesn't have to match Lincoln Riley's electricity", 'description': 'With Lincoln Riley taking over at USC, all eyes and interest will be on the Trojans whether or not UCLA coach Chip Kelly and the Bruins can keep up.', 'url': 'https://www.latimes.com/sports/story/2022-04-05/commentary-what-impact-is-usc-coach-lincoln-riley-having-on-ucla-coach-chip-kelly', 'urlToImage': 'https://ca-times.brightspotcdn.com/dims4/default/0cab9a1/2147483647/strip/true/crop/6909x3627+1+516/resize/1200x630!/quality/90/?url=https%3A%2F%2Fcalifornia-times-brightspot.s3.amazonaws.com%2F0d%2F57%2Ffca4698a481595bd69a1d7ee12c3%2Fhawaii-ucla-football-65579.jpg', 'publishedAt': '2022-04-05T12:00:44Z', 'content': 'Last week at UCLA football practice, I asked Chip Kelly about Lincoln Rileys next-level use of the transfer portal a reference that anyone who is remotely engaged in following college football would … [+5929 chars]'}, {'source': {'id': None, 'name': 'Daily Mail'}, 'author': 'Associated, Alastair Talbot', 'title': 'Betty Reid Soskin - the oldest active Park Ranger in the US - retires at 100 years old', 'description': 'Betty Reid Soskin retired at the age of 100 on March 31 after serving more than 15 years as a park ranger. She was also once named California Woman of the year in 1995 for her civil rights activism.', 'url': 'https://www.dailymail.co.uk/news/article-10681861/Betty-Reid-Soskin-oldest-active-Park-Ranger-retires-100-years-old.html', 'urlToImage': 'https://i.dailymail.co.uk/1s/2022/04/03/22/56171465-0-image-a-76_1649021026619.jpg', 'publishedAt': '2022-04-03T21:25:30Z', 'content': "The nation's oldest active park ranger is hanging up her Smokey hat at the age of 100 after only starting to work for the National Park Service at 84-years-old to tell the untold stories of Black peo… [+5492 chars]"}, {'source': {'id': None, 'name': 'Los Angeles Times'}, 'author': 'Eric Sondheimer', 'title': 'Zach Charbonnet determined to be bigger, faster, stronger for UCLA in 2022', ' ...

# %%
# fetching data from newsapi

# %%
news_source=[]
title=[]
url = []
description = []
date =[]


for articles in result['articles']:
  news_source.append(articles['source']['name'])
  title.append(articles['title'])
  url.append(articles['url'])
  description.append(articles['description'])
  date.append(articles['publishedAt'])

# %%
# Creating DataFrame

# %%
pip install google.colab
# Out:
# Collecting google.colab
#   Downloading google-colab-1.0.0.tar.gz (72 kB)
#      -------------------------------------- 72.9/72.9 KB 803.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting google-auth~=1.4.0
#   Downloading google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.2/64.2 KB ? eta 0:00:00
# Collecting ipykernel~=4.6.0
#   Downloading ipykernel-4.6.1-py3-none-any.whl (104 kB)
#      ------------------------------------ 104.5/104.5 KB 547.9 kB/s eta 0:00:00
# Collecting ipython~=5.5.0
#   Downloading ipython-5.5.0-py3-none-any.whl (758 kB)
#      ------------------------------------ 758.9/758.9 KB 295.7 kB/s eta 0:00:00
# Collecting notebook~=5.2.0
#   Downloading notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
#      ---------------------------------------- 8.0/8.0 MB 185.0 kB/s eta 0:00:00
# Collecting six~=1.12.0
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting pandas~=0.24.0
#   Downloading pandas-0.24.2-cp37-cp37m-win_amd64.whl (9.0 MB)
#      ---------------------------------------- 9.0/9.0 MB 284.6 kB/s eta 0:00:00
# Collecting portpicker~=1.2.0
#   Downloading portpicker-1.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting requests~=2.21.0
#   Downloading requests-2.21.0-py2.py3-none-any.whl (57 kB)
#      -------------------------------------- 58.0/58.0 KB 277.6 kB/s eta 0:00:00
# Collecting tornado~=4.5.0
#   Downloading tornado-4.5.3.tar.gz (484 kB)
#      ------------------------------------ 484.2/484.2 KB 139.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting rsa>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Requirement already satisfied: cachetools>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from google-auth~=1.4.0->google.colab) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\admin\anaconda3\lib\site-packages (from google-auth~=1.4.0->google.colab) (0.2.8)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\admin\anaconda3\lib\site-packages (from ipykernel~=4.6.0->google.colab) (5.1.1)
# Requirement already satisfied: jupyter-client in c:\users\admin\anaconda3\lib\site-packages (from ipykernel~=4.6.0->google.colab) (7.2.2)
# Requirement already satisfied: decorator in c:\users\admin\anaconda3\lib\site-packages (from ipython~=5.5.0->google.colab) (4.4.0)
# Requirement already satisfied: pickleshare in c:\users\admin\anaconda3\lib\site-packages (from ipython~=5.5.0->google.colab) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in c:\users\admin\anaconda3\lib\site-packages (from ipython~=5.5.0->google.colab) (0.8.1)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from ipython~=5.5.0->google.colab) (0.4.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\admin\anaconda3\lib\site-packages (from ipython~=5.5.0->google.colab) (41.0.1)
# Collecting prompt-toolkit<2.0.0,>=1.0.4
#   Downloading prompt_toolkit-1.0.18-py3-none-any.whl (245 kB)
#      ------------------------------------- 245.4/245.4 KB 97.7 kB/s eta 0:00:00
# Requirement already satisfied: pygments in c:\users\admin\anaconda3\lib\site-packages (from ipython~=5.5.0->google.colab) (2.4.2)
# Requirement already satisfied: jupyter-core in c:\users\admin\anaconda3\lib\site-packages (from notebook~=5.2.0->google.colab) (4.9.2)
# Requirement already satisfied: nbconvert in c:\users\admin\anaconda3\lib\site-packages (from notebook~=5.2.0->google.colab) (5.5.0)
# Requirement already satisfied: nbformat in c:\users\admin\anaconda3\lib\site-packages (from notebook~=5.2.0->google.colab) (4.4.0)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from notebook~=5.2.0->google.colab) (2.10.1)
# Requirement already satisfied: ipython-genutils in c:\users\admin\anaconda3\lib\site-packages (from notebook~=5.2.0->google.colab) (0.2.0)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas~=0.24.0->google.colab) (2.8.2)
# Requirement already satisfied: pytz>=2011k in c:\users\admin\anaconda3\lib\site-packages (from pandas~=0.24.0->google.colab) (2019.1)
# Requirement already satisfied: numpy>=1.12.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas~=0.24.0->google.colab) (1.21.5)
# Collecting urllib3<1.25,>=1.21.1
#   Downloading urllib3-1.24.3-py2.py3-none-any.whl (118 kB)
#      ------------------------------------ 118.8/118.8 KB 210.4 kB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests~=2.21.0->google.colab) (2021.10.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests~=2.21.0->google.colab) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests~=2.21.0->google.colab) (2.8)
# Requirement already satisfied: wcwidth in c:\users\admin\anaconda3\lib\site-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython~=5.5.0->google.colab) (0.1.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\admin\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=1.4.0->google.colab) (0.4.8)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->notebook~=5.2.0->google.colab) (1.1.1)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (22.3.0)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (1.5.5)
# Collecting jupyter-client
#   Downloading jupyter_client-7.2.1-py3-none-any.whl (130 kB)
#      ------------------------------------ 130.4/130.4 KB 639.4 kB/s eta 0:00:00
#   Downloading jupyter_client-7.2.0-py3-none-any.whl (130 kB)
#      ------------------------------------ 130.5/130.5 KB 452.2 kB/s eta 0:00:00
#   Downloading jupyter_client-7.1.2-py3-none-any.whl (130 kB)
#      ------------------------------------ 130.3/130.3 KB 427.1 kB/s eta 0:00:00
# Requirement already satisfied: entrypoints in c:\users\admin\anaconda3\lib\site-packages (from jupyter-client->ipykernel~=4.6.0->google.colab) (0.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from jupyter-core->notebook~=5.2.0->google.colab) (223)
# Requirement already satisfied: testpath in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.4.2)
# Requirement already satisfied: bleach in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (3.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (1.4.2)
# Requirement already satisfied: defusedxml in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.6.0)
# Requirement already satisfied: mistune>=0.8.1 in c:\users\admin\anaconda3\lib\site-packages (from nbconvert->notebook~=5.2.0->google.colab) (0.8.4)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from nbformat->notebook~=5.2.0->google.colab) (3.0.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google.colab) (19.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook~=5.2.0->google.colab) (0.14.11)
# Requirement already satisfied: webencodings in c:\users\admin\anaconda3\lib\site-packages (from bleach->nbconvert->notebook~=5.2.0->google.colab) (0.5.1)
# Building wheels for collected packages: google.colab, portpicker, tornado
#   Building wheel for google.colab (setup.py): started
#   Building wheel for google.colab (setup.py): finished with status 'done'
#   Created wheel for google.colab: filename=google_colab-1.0.0-py2.py3-none-any.whl size=102299 sha256=55bce9d1f6428044003aceeddb9c3c1a65b252f263939364f2145a91d36ec88c
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\f6\3b\58\f34ea9045a7c69bd5634978bf25ac60277e90997d9e6e74192
#   Building wheel for portpicker (setup.py): started
#   Building wheel for portpicker (setup.py): finished with status 'done'
#   Created wheel for portpicker: filename=portpicker-1.2.0-py3-none-any.whl size=13372 sha256=9cf05d7a065817cdccab03f41cdc673e6e92a6c6cf27863654165749fbe26c72
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\73\0c\f5\35977446e45e818e6b848be3d41e7f38298a5102f4dcda21c6
#   Building wheel for tornado (setup.py): started
#   Building wheel for tornado (setup.py): finished with status 'done'
#   Created wheel for tornado: filename=tornado-4.5.3-cp37-cp37m-win_amd64.whl size=420780 sha256=b6df64138dcb7e555b877df85b76cc8e933f944b14ff033676be934dc03e4ecd
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\a2\45\43\36ec7a893e16c1212a6b1505ded0a2d73cf8e863a0227c8e04
# Successfully built google.colab portpicker tornado
# Installing collected packages: tornado, portpicker, urllib3, six, rsa, requests, prompt-toolkit, google-auth, pandas, jupyter-client, ipython, ipykernel, notebook, google.colab
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\admin\\anaconda3\\lib\\site-packages\\~ornado\\speedups.cp37-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
data = {'News_source': news_source,'Title':title,'Url':url,'Description':description,'Date':date}
df = pd.DataFrame(data)
df.head()


from google.colab import files

df.to_csv('virat_kohli.csv',encoding = 'utf-8-sig')
files.download('virat_kohli.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7928\2203293092.py in <module>
#       4
#       5
# ----> 6 from google.colab import files
#       7
#       8 df.to_csv('virat_kohli.csv',encoding = 'utf-8-sig')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import numpy as np
import seaborn as sns
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
nltk.download("vader_lexicon")
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
from IPython import display
from pprint import pprint
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
sns.set(style ='darkgrid',context ='talk',palette='Dark2')

# %%
sia = SIA()
desc = []
for line in description:
  scores = sia.polarity_scores(line)
  scores['headline'] = line
  desc.append(scores)
df1 = pd.DataFrame.from_records(desc)
df1
# Out:
#       neg    neu  ...  compound                                           headline
# 0   0.000  0.891  ...    0.5859  India vs South Africa: Rishabh Pant remained u...
# 1   0.000  0.721  ...    0.7351  "It's safe to say that Heli came to my rescue ...
# 2   0.000  0.904  ...    0.6258  If there is one thing besides that comes to mi...
# 3   0.000  0.758  ...    0.8360  SAN DIEGO, Jan. 13, 2022 /PRNewswire/ -- DERMA...
# 4   0.000  0.664  ...    0.8225  DERMALA, a consumer dermatology company that d...
# 5   0.054  0.734  ...    0.8074  Captain Virat Kohli and Rishabh Pant have stee...
# 6   0.000  1.000  ...    0.0000  India vs South Africa, 3rd Test: Ajinkya Rahan...
# 7   0.000  0.901  ...    0.3612  Pant scored a crucial half-century while Kohli...
# 8   0.096  0.904  ...   -0.5106  This was the seventh occasion when Pujara fail...
# 9   0.000  0.942  ...    0.3400  After batsman Ajinkya Rahane delivered yet ano...
# 10  0.096  0.904  ...   -0.5106  South Africa vs India, 3rd Test: Cheteshwar Pu...
# 11  0.169  0.831  ...   -0.6249  The Proteas are fighting with everything they ...
# 12  0.000  1.000  ...    0.0000  All the Indian fielders and those sitting in t...
# 13  0.051  0.888  ...    0.1280  <ol><li>IND vs SA: Fans Hilariously Troll Chet...
# 14  0.070  0.930  ...   -0.4019  <ol><li>India vs South Africa Live Score, 3rd ...
# 15  0.102  0.825  ...   -0.2960  South Africa vs India: Team India got off to t...
# 16  0.000  0.769  ...    0.6486  India vs South Africa: India are looking to po...
# 17  0.000  1.000  ...    0.0000  Jatin Sarna said he has declined more than 12 ...
# 18  0.000  0.776  ...    0.8316  South Africa vs India: Former England captain ...
# 19  0.000  1.000  ...    0.0000  Live Cricket Score India vs South Africa: Indi...
#
# [20 rows x 5 columns]

# %%
df1['label']= 0 
df1.loc[df1['compound']>0.1,'label'] = 1
df1.loc[df1['compound']< -0.1,'label'] = -1
df1
# Out:
#       neg    neu  ...                                           headline  label
# 0   0.000  0.891  ...  India vs South Africa: Rishabh Pant remained u...      1
# 1   0.000  0.721  ...  "It's safe to say that Heli came to my rescue ...      1
# 2   0.000  0.904  ...  If there is one thing besides that comes to mi...      1
# 3   0.000  0.758  ...  SAN DIEGO, Jan. 13, 2022 /PRNewswire/ -- DERMA...      1
# 4   0.000  0.664  ...  DERMALA, a consumer dermatology company that d...      1
# 5   0.054  0.734  ...  Captain Virat Kohli and Rishabh Pant have stee...      1
# 6   0.000  1.000  ...  India vs South Africa, 3rd Test: Ajinkya Rahan...      0
# 7   0.000  0.901  ...  Pant scored a crucial half-century while Kohli...      1
# 8   0.096  0.904  ...  This was the seventh occasion when Pujara fail...     -1
# 9   0.000  0.942  ...  After batsman Ajinkya Rahane delivered yet ano...      1
# 10  0.096  0.904  ...  South Africa vs India, 3rd Test: Cheteshwar Pu...     -1
# 11  0.169  0.831  ...  The Proteas are fighting with everything they ...     -1
# 12  0.000  1.000  ...  All the Indian fielders and those sitting in t...      0
# 13  0.051  0.888  ...  <ol><li>IND vs SA: Fans Hilariously Troll Chet...      1
# 14  0.070  0.930  ...  <ol><li>India vs South Africa Live Score, 3rd ...     -1
# 15  0.102  0.825  ...  South Africa vs India: Team India got off to t...     -1
# 16  0.000  0.769  ...  India vs South Africa: India are looking to po...      1
# 17  0.000  1.000  ...  Jatin Sarna said he has declined more than 12 ...      0
# 18  0.000  0.776  ...  South Africa vs India: Former England captain ...      1
# 19  0.000  1.000  ...  Live Cricket Score India vs South Africa: Indi...      0
#
# [20 rows x 6 columns]

# %%
print('positive headlines:\n')
pprint(list(df1[df1['label'] == 1].headline)[:5],width = 100)

print('\nnegative headlines:\n')
pprint(list(df1[df1['label'] == -1].headline)[:5],width = 100)
# Out:
# positive headlines:
#
# ['India vs South Africa: Rishabh Pant remained unbeaten on 100 as India were bowled out for 198 in '
#  'the second innings. South Africa were set a target of 212 to win the match.',
#  '"It\'s safe to say that Heli came to my rescue on the sets of Meri Tarah, said Himansh',
#  'If there is one thing besides that comes to mind when we think of Virat Kohli is that he is an '
#  'almost flawless cricketer. However, if we take that out of the equation, the other thing that '
#  "gets us going is the man's energy - it is magnetic.Known for his promi…",
#  'SAN DIEGO, Jan. 13, 2022 /PRNewswire/ -- DERMALA, a consumer dermatology company that develops '
#  "novel treatments for chronic skin conditions, announces the brand's Grand Prize recognition in "
#  'the global pitch competition; Colgate Connect Challenge. Dermala Awar…',
#  'DERMALA, a consumer dermatology company that develops novel treatments for chronic skin '
#  "conditions, announces the brand's Grand Prize recognition in the..."]
#
# negative headlines:
#
# ['This was the seventh occasion when Pujara failed to add to his overnight tally. The right-handed '
#  'was previously tied with former New Zealand all-rounder Chris Cairns and South Africa legend '
#  'Jacques Kallis.',
#  'South Africa vs India, 3rd Test: Cheteshwar Pujara and Ajinkya Rahane failed to put runs on the '
#  'board yet again as India found themselves wanting in the first hour on Day 3.',
#  'The Proteas are fighting with everything they have, trying desperately to give themselves '
#  'something manageable to chase in the third and final Test against India at Newlands.',
#  '<ol><li>India vs South Africa Live Score, 3rd Test, Day 3: Kohli, Pant key for IND after Pujara, '
#  'Rahane disappoint again\xa0\xa0Hindustan Times\r\n'
#  '</li><li>Live match blog - India vs South Africa 3rd Test 2021/22 - Cricket Insights\xa0\xa0'
#  'ESPNcricinfo.com\r\n'
#  "</li><li>'79 Ove…",
#  'South Africa vs India: Team India got off to the worst possible start with Cheteshwar Pujara '
#  'departing on the second ball of Day 3, thanks to a one-handed stunner by Keegan Petersen in the '
#  'leg-slip region.']

# %%
print(df1.label.value_counts())
print(df1.label.value_counts(normalize=True)*100)
# Out:
#  1    11
# -1     5
#  0     4
# Name: label, dtype: int64
#  1    55.0
# -1    25.0
#  0    20.0
# Name: label, dtype: float64

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (8,8))
counts = df1.label.value_counts(normalize=True)*100
sns.barplot(x=counts.index, y=counts,ax=ax)
ax.set_xticklabels(['negative','neutral','positive'])
ax.set_ylabel('percentage')
plt.show()
