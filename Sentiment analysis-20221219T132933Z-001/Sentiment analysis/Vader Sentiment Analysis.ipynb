# %%
 # !pip install vaderSentiment
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\srini\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\srini\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\srini\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\srini\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\srini\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\srini\anaconda3\lib\site-packages)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd

# %%
def sentiment_scores(sentence):
 
    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()
 
    #Disctionary object created
    sentiment_dict = sid_obj.polarity_scores(sentence)
     
    print("Overall sentiment dictionary is : ", sentiment_dict)
    print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative")
    print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral")
    print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive")
 
    print("Sentence Overall Rated As", end = " ")
 
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] >= 0.05 :
        print("Positive")
        return "Positive"
 
    elif sentiment_dict['compound'] <= - 0.05 :
        print("Negative")
        return "Negative"
 
    else :
        print("Neutral")
        return "Neutral"

# %%
sentence1 = "Dominant Australia close in on series win"
sentiment_scores(sentence1)
# Out:
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.612, 'pos': 0.388, 'compound': 0.5859}
# sentence was rated as  0.0 % Negative
# sentence was rated as  61.199999999999996 % Neutral
# sentence was rated as  38.800000000000004 % Positive
# Sentence Overall Rated As Positive
# 'Positive'

# %%
sentence2 = "Kelechi Iheanacho was on target as Nigeria comfortably beat seven-time champions Egypt in their Africa Cup of Nations Group D opener"
sentiment_scores(sentence2)
# Out:
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.754, 'pos': 0.246, 'compound': 0.7351}
# sentence was rated as  0.0 % Negative
# sentence was rated as  75.4 % Neutral
# sentence was rated as  24.6 % Positive
# Sentence Overall Rated As Positive
# 'Positive'

# %%
sentence3 = "Today is gloomy"
sentiment_scores(sentence3)
# Out:
# Overall sentiment dictionary is :  {'neg': 0.444, 'neu': 0.556, 'pos': 0.0, 'compound': -0.1531}
# sentence was rated as  44.4 % Negative
# sentence was rated as  55.60000000000001 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Negative
# 'Negative'

# %%
df = pd.read_csv("kohli.csv")
df.head()
# Out:
#    Unnamed: 0          Date  \
# 0           1  Jan 11, 2022
# 1           2  Jan 11, 2022
# 2           3  Jan 11, 2022
# 3           4  Jan 10, 2022
# 4           5  Jan 10, 2022
#
#                                                 News  \
# 0  India vs South Africa 3rd Test: India Make Two...
# 1  South Africa vs India, 3rd Test, Day 1 Live: C...
# 2  South Africa vs India: Harbhajan Singh Gives B...
# 3  "Won't Say I Missed Him": South Africa Captain...
# 4  Watch: Booming Pulls, Assertive Drives - Virat...
#
#                                          Discription  \
# 0  India made two changes to their playing XI for...
# 1  India vs South Africa, 3rd Test, Day 1 Live Up...
# 2  SA vs IND: Kohli, who had missed the second Te...
# 3  South Africa captain Dean Elgar said he "did n...
# 4  India vs South Africa: Ahead of the third Test...
#
#                                                links
# 0  https://sports.ndtv.com/south-africa-vs-india-...
# ...

# %%
df['Discription'][0]
# Out:
# 'India made two changes to their playing XI for the decider against South Africa at the Newlands in Cape Town.'

# %%
final = []

for i in range(len(df)):
    final.append(sentiment_scores(df['Discription'][i]))
# Out:
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.913, 'pos': 0.087, 'compound': 0.2023}
# sentence was rated as  0.0 % Negative
# sentence was rated as  91.3 % Neutral
# sentence was rated as  8.7 % Positive
# Sentence Overall Rated As Positive
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
# Overall sentiment dictionary is :  {'neg': 0.123, 'neu': 0.877, 'pos': 0.0, 'compound': -0.5423}
# sentence was rated as  12.3 % Negative
# sentence was rated as  87.7 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Negative
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.5606}
# sentence was rated as  0.0 % Negative
# sentence was rated as  87.0 % Neutral
# sentence was rated as  13.0 % Positive
# ...

# %%
final
# Out:
# ['Positive',
#  'Neutral',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative']

# %%
final_head = []

for i in range(len(df)):
    final_head.append(sentiment_scores(df['News'][i]))
# Out:
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.2235}
# sentence was rated as  0.0 % Negative
# sentence was rated as  89.4 % Neutral
# sentence was rated as  10.6 % Positive
# Sentence Overall Rated As Positive
# ...

# %%
final_head
# Out:
# ['Neutral',
#  'Neutral',
#  'Neutral',
#  'Positive',
#  'Neutral',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Neutral',
#  'Neutral']
